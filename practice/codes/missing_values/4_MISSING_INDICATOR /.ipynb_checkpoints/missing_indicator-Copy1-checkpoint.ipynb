# %%
import pandas as pd 
df=pd.read_csv('train (1).csv',usecols=['Age','Fare','Survived'])

# %%
df_Age=df[['Age']]

# %%
from sklearn.impute import MissingIndicator

# %%
mi=MissingIndicator()

# %%
df_Age_miss=mi.fit_transform(df_Age)

# %%
df_Age_miss=pd.DataFrame(df_Age_miss,columns=['Age_miss'])

# %%
df=pd.concat([df,df_Age_miss],axis=1)

# %%
df
# Out:
#      Survived   Age     Fare  Age_miss
# 0           0  22.0   7.2500     False
# 1           1  38.0  71.2833     False
# 2           1  26.0   7.9250     False
# 3           1  35.0  53.1000     False
# 4           0  35.0   8.0500     False
# ..        ...   ...      ...       ...
# 886         0  27.0  13.0000     False
# 887         1  19.0  30.0000     False
# 888         0   NaN  23.4500      True
# 889         1  26.0  30.0000     False
# 890         0  32.0   7.7500     False
#
# [891 rows x 4 columns]

# %%
df.isnull().sum()
# Out:
# Survived      0
# Age         177
# Fare          0
# Age_miss      0
# dtype: int64

# %%
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer

# %%
trf=ColumnTransformer(
    transformers=[
        ('impute',SimpleImputer(),['Age']),
       
    ],remainder='passthrough')

# %%
dff=trf.fit_transform(df)
dff=pd.DataFrame(dff,columns=['Age','Survived','Fare','Age_miss'])
dff.isnull().sum()
# Out:
# Age         0
# Survived    0
# Fare        0
# Age_miss    0
# dtype: int64

# %%
dff
# Out:
#            Age Survived     Fare Age_miss
# 0         22.0        0     7.25    False
# 1         38.0        1  71.2833    False
# 2         26.0        1    7.925    False
# 3         35.0        1     53.1    False
# 4         35.0        0     8.05    False
# ..         ...      ...      ...      ...
# 886       27.0        0     13.0    False
# 887       19.0        1     30.0    False
# 888  29.699118        0    23.45     True
# 889       26.0        1     30.0    False
# 890       32.0        0     7.75    False
#
# [891 rows x 4 columns]

# %%
dff=dff.drop(['Age_miss'],axis=1)
dff.head()
# Out:
#     Age Survived     Fare
# 0  22.0        0     7.25
# 1  38.0        1  71.2833
# 2  26.0        1    7.925
# 3  35.0        1     53.1
# 4  35.0        0     8.05

# %%
dff
# Out:
#            Age Survived     Fare
# 0         22.0        0     7.25
# 1         38.0        1  71.2833
# 2         26.0        1    7.925
# 3         35.0        1     53.1
# 4         35.0        0     8.05
# ..         ...      ...      ...
# 886       27.0        0     13.0
# 887       19.0        1     30.0
# 888  29.699118        0    23.45
# 889       26.0        1     30.0
# 890       32.0        0     7.75
#
# [891 rows x 3 columns]

# %%
from sklearn.model_selection import train_test_split
x=dff[['Age','Fare']]
y=dff[['Survived']]
# x_train,x_test,y_train,y_test=train_test_split (x,y)
x_train
y_train

# %%
x_train
# Out:
#            Age     Fare
# 674  29.699118      0.0
# 344       36.0     13.0
# 877       19.0   7.8958
# 393       23.0  113.275
# 7          2.0   21.075
# ..         ...      ...
# 590       35.0    7.125
# 438       64.0    263.0
# 702       18.0  14.4542
# 248       37.0  52.5542
# 388  29.699118   7.7292
#
# [668 rows x 2 columns]

# %%
from sklearn.linear_model import LinearRegression 
li= LinearRegression ()

# %%
x_train 
y_train=pd.DataFrame(y_train,columns=['Survived'])

# %%
y_train
# Out:
#     Survived
# 0          0
# 1          0
# 2          0
# 3          1
# 4          0
# ..       ...
# 663        0
# 664        0
# 665        0
# 666        1
# 667        0
#
# [668 rows x 1 columns]

# %%
li.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import accuracy_score

# %%
y_test=pd.DataFrame(y_test,columns=['Survived'])

# %%
y_test
# Out:
#     Survived
# 339        0
# 501        0
# 731        0
# 110        0
# 325        1
# ..       ...
# 550        1
# 30         0
# 185        0
# 442        0
# 811        0
#
# [223 rows x 1 columns]

# %%
y_pred=clf.predict(x_test)
y_pred=pd.DataFrame(y_pred,columns=['Survived'])
y_pred
print('accuracy_score',accuracy_score(y_pred,y_test))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[232], line 4
#       2 y_pred=pd.DataFrame(y_pred,columns=['Survived'])
#       3 y_pred
# ----> 4 print('accuracy_score',accuracy_score(y_pred,y_test))
#
# File /home/linuxbrew/.linuxbrew/Cellar/jupyterlab/4.5.3/libexec/lib/python3.14/site-packages/sklearn/utils/_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
#     220     # When the function is just a wrapper around an estimator, we allow
#     221     # the function to delegate validation to the estimator, but we replace
# ...
