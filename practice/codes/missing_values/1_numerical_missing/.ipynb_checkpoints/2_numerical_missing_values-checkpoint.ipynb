# %% [markdown]
# ***missing numerical data imputation***

# %%
import pandas as pd 
df=pd.read_csv('titanic_toy.csv')

# %%
df.isnull().mean()
# Out:
# Age         0.198653
# Fare        0.050505
# Family      0.000000
# Survived    0.000000
# dtype: float64

# %%
from sklearn.model_selection import train_test_split
x=df.iloc[:,0:3]
y=df.iloc[:,-1]

x_train,x_test,y_train,y_test=train_test_split(x,y)
x_train
# Out:
#       Age      Fare  Family
# 380  42.0  227.5250       0
# 614  35.0    8.0500       0
# 830  15.0   14.4542       1
# 151  22.0   66.6000       1
# 56   21.0   10.5000       0
# ..    ...       ...     ...
# 466   NaN       NaN       0
# 499  24.0    7.7958       0
# 602   NaN   42.4000       0
# 446  13.0   19.5000       1
# 16    2.0   29.1250       5
#
# [668 rows x 3 columns]

# %% [markdown]
# ***filling of missing value by mean median using pandas***

# %%
x_train['new_Age_mean']=x_train['Age'].fillna(x_train['Age'].mean())
x_train['new_Age_median']=x_train['Age'].fillna(x_train['Age'].median())

x_train['new_Fare_mean']=x_train['Fare'].fillna(x_train['Fare'].mean())
x_train['new_Fare_median']=x_train['Fare'].fillna(x_train['Fare'].median())

# %%
x_train
# Out:
#       Age      Fare  Family  new_Age_mean  new_Age_median  new_Fare_mean  \
# 380  42.0  227.5250       0     42.000000            42.0     227.525000
# 614  35.0    8.0500       0     35.000000            35.0       8.050000
# 830  15.0   14.4542       1     15.000000            15.0      14.454200
# 151  22.0   66.6000       1     22.000000            22.0      66.600000
# 56   21.0   10.5000       0     21.000000            21.0      10.500000
# ..    ...       ...     ...           ...             ...            ...
# 466   NaN       NaN       0     29.689667            28.0      32.520826
# 499  24.0    7.7958       0     24.000000            24.0       7.795800
# 602   NaN   42.4000       0     29.689667            28.0      42.400000
# 446  13.0   19.5000       1     13.000000            13.0      19.500000
# 16    2.0   29.1250       5      2.000000             2.0      29.125000
#
#      new_Fare_median
# 380         227.5250
# 614           8.0500
# 830          14.4542
# ...

# %%
def variance (y) :
    print('age variance before ',y['Age'].var())
    print('age variance after mean ',y['new_Age_mean'].var())
    print('age variance after mean ',y['new_Age_median'].var())
    
    print('fare variance before ',y['Fare'].var())
    print('age variance after mean ',y['new_Fare_mean'].var())
    print('age variance after mean ',y['new_Fare_median'].var())

# %%
variance(x_train)
# Out:
# age variance before  206.20567447124304
# age variance after mean  166.63397082458772
# age variance after mean  167.07686860731312
# fare variance before  2264.3156193843447
# age variance after mean  2148.893233988441
# age variance after mean  2164.604648318454

# %%
import matplotlib.pyplot as plp
import seaborn as sns

# %%
def draw(y) :
    fig, (ax1,ax2) =plp.subplots(1,2,figsize=(12,5))
    ax1.set_title('age')
    sns.kdeplot(y['Age'],  ax= ax1)
    sns.kdeplot(y['new_Age_mean'],  ax= ax1)
    sns.kdeplot(y['new_Age_median'],  ax= ax1)
    
    ax2.set_title('Fare')
    sns.kdeplot(y['Age'], ax= ax2)
    sns.kdeplot(y['new_Age_mean'], ax= ax2)
    sns.kdeplot(y['new_Age_median'],ax= ax2)

# %%
def draw(y,col,col1) :
    fig, (ax1,ax2) =plp.subplots(1,2,figsize=(12,5))
    ax1.set_title(col)
    sns.kdeplot(y[col],  ax= ax1)
    sns.kdeplot(y[f'new_{col}_mean'],  ax= ax1)
    sns.kdeplot(y[f'new_{col}_median'],  ax= ax1)
    
    ax2.set_title(col1)
    sns.kdeplot(y[col1], ax= ax2)
    sns.kdeplot(y[f'new_{col1}_mean'], ax= ax2)
    sns.kdeplot(y[f'new_{col1}_median'],ax= ax2)

# %%
draw(x_train,'Age','Fare')

# %%
x_train.cov()
# Out:
#                         Age         Fare     Family  new_Age_mean  \
# Age              206.205674    86.836385  -6.254334    206.205674
# Fare              86.836385  2264.315619  18.912896     69.701470
# Family            -6.254334    18.912896   2.671422     -5.054102
# new_Age_mean     206.205674    69.701470  -5.054102    166.633971
# new_Age_median   206.205674    73.071326  -5.021883    166.633971
# new_Fare_mean     81.857200  2264.315619  17.948821     66.148472
# new_Fare_median   79.617145  2264.315619  18.166742     64.338293
#
#                  new_Age_median  new_Fare_mean  new_Fare_median
# Age                  206.205674      81.857200        79.617145
# Fare                  73.071326    2264.315619      2264.315619
# Family                -5.021883      17.948821        18.166742
# new_Age_mean         166.633971      66.148472        64.338293
# new_Age_median       167.076869      69.346551        67.467212
# ...

# %%
x_train.corr()
# Out:
#                       Age      Fare    Family  new_Age_mean  new_Age_median  \
# Age              1.000000  0.117678 -0.287688      1.000000        1.000000
# Fare             0.117678  1.000000  0.240088      0.111911        0.117193
# Family          -0.287688  0.240088  1.000000     -0.239547       -0.237704
# new_Age_mean     1.000000  0.111911 -0.239547      1.000000        0.998674
# new_Age_median   1.000000  0.117193 -0.237704      0.998674        1.000000
# new_Fare_mean    0.115796  1.000000  0.236896      0.110543        0.115734
# new_Fare_median  0.112140  1.000000  0.238900      0.107127        0.112188
#
#                  new_Fare_mean  new_Fare_median
# Age                   0.115796         0.112140
# Fare                  1.000000         1.000000
# Family                0.236896         0.238900
# new_Age_mean          0.110543         0.107127
# new_Age_median        0.115734         0.112188
# new_Fare_mean         1.000000         0.996364
# ...

# %%
fig, (ax1,ax2,ax3) =plp.subplots(1,3,figsize=(12,5))

sns.boxplot(x_train['Age'],ax=ax1)
sns.boxplot(x_train['new_Age_mean'],ax=ax2)
sns.boxplot(x_train['new_Age_median'],ax=ax3)
# Out:
# <Axes: ylabel='new_Age_median'>

# %%
fig, (ax1,ax2,ax3) =plp.subplots(1,3,figsize=(12,5))

sns.boxplot(x_train['Fare'],ax=ax1)
sns.boxplot(x_train['new_Fare_mean'],ax=ax2)
sns.boxplot(x_train['new_Fare_median'],ax=ax3)
# Out:
# <Axes: ylabel='new_Fare_median'>

# %% [markdown]
# ***use of scikit learn class to fill missing value by mean median ***

# %%
x_train=x_train[['Age','Fare','Family']]

# %%
x_train
# Out:
#       Age      Fare  Family
# 380  42.0  227.5250       0
# 614  35.0    8.0500       0
# 830  15.0   14.4542       1
# 151  22.0   66.6000       1
# 56   21.0   10.5000       0
# ..    ...       ...     ...
# 466   NaN       NaN       0
# 499  24.0    7.7958       0
# 602   NaN   42.4000       0
# 446  13.0   19.5000       1
# 16    2.0   29.1250       5
#
# [668 rows x 3 columns]

# %%
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
trf= ColumnTransformer(
    transformers=[
   ('trf1',SimpleImputer(strategy='mean'),['Age']),
   ('trf2',SimpleImputer(strategy='median'),['Fare'])
        
    
    
    
],remainder='passthrough')

# %%
x_train_impute=trf.fit_transform(x_train)
x_test_impute=trf.fit_transform(x_test)

# %%
trf.named_transformers_['trf1'].statistics_
# Out:
# array([29.72844828])
