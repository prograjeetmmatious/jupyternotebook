# %%
import pandas as pd 
import numpy as np
import seaborn as sns 
df=pd.read_csv('placement (2).csv')
df.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
x=df.iloc[:,0:1]
y=df.iloc[:,1:]
from sklearn.model_selection import train_test_split 
x_train,x_test,y_train,y_test=train_test_split(x,y)
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=pd.DataFrame(lr.predict(x_test))

# %%
import matplotlib.pyplot as plp
plp.scatter(df['cgpa'],df['package'])
plp.plot(x_train,lr.predict(x_train),color='red')

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
y_pred=lr.predict(x_test)

# %%
y_test=y_test.values

# %%
print('mea is ',mean_absolute_error(y_test,y_pred))
# Out:
# mea is  0.2719692684162727

# %%
print('mse is ',mean_squared_error(y_test,y_pred))
# Out:
# mse is  0.13395998969892586

# %%
print('root mean square error  ',np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# root mean square error   0.366005450367786

# %%
print('r2scre is ',r2_score(y_test,y_pred))
# Out:
# r2scre is  0.734888106981947

# %%
# I AM GOING TO SHOW YOU HOW ADJAACENT R2SCORE GET AFFECTED AND R2 SCORE

# %%
df.shape
# Out:
# (200, 2)

# %%
new_df=df.copy()
new_df['new_feature']=np.random.random(200)
for i in range(200)
  new_df.columns=new_df.columns*10
new_df
# Out:
#   Cell In[92], line 3
#     for i in range(200)
#                        ^
# SyntaxError: expected ':'

# %%
x_new=new_df.iloc[:,0:2]
y_new=new_df.iloc[:,2:]
x_new_train,x_new_test,y_new_train,y_new_test=train_test_split(x_new,y_new)
from sklearn.linear_model import LinearRegression 
lr2=LinearRegression()
lr2.fit(x_new_train,y_new_train)
y_new_pred=lr2.predict(x_new_test)
y_new_test=y_new_test.values
print('r2scre is ',r2_score(y_new_test,y_new_pred))
# Out:
# r2scre is  0.040987690823684586
