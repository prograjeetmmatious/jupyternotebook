# %%
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plp

# %%
df=pd.read_csv('placement (2).csv')

# %%
#plp.scatter(df['cgpa'],df['package'])
plp.plot(x_train,lr.predict(x_train),color='red')
plp.xlabel('cgpa')
plp.ylabel('package')
# Out:
# Text(0, 0.5, 'package')

# %%
x=df.iloc[:,0:1]
y=df.iloc[:,1:]

# %%
from sklearn.model_selection import train_test_split 
x_train,x_test,y_train,y_test=train_test_split(x,y,test_sixze=0.2,random_state=2)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
x_test.head()
# Out:
#      cgpa
# 72   7.78
# 41   6.89
# 61   5.48
# 156  7.38
# 112  8.58

# %%
lr.predict(x_test.iloc[[0]])
# Out:
# array([[3.41506474]])

# %%
y_test.head()
# Out:
#      package
# 72      3.62
# 41      2.70
# 61      1.61
# 156     3.13
# 112     4.10

# %%
lr.coef_
# Out:
# array([[0.56013319]])

# %%
lr.intercept_
# Out:
# array([-0.94277145])
